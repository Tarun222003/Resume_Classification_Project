# %%
import pandas as pd
import os

# List of uploaded files
uploaded_files = [
    '/content/Internship_Susovan Bag_Musquare Technologies.docx',
    '/content/Internship_Ravali_Musquare Technologies (1).docx'
]

# Create the DataFrame
df = pd.DataFrame({
    'Resume': uploaded_files,
    'category': 'Intern Resumes'
})

# Display the DataFrame
display(df)
# Out:
#                                               Resume        category
# 0  /content/Internship_Susovan Bag_Musquare Techn...  Intern Resumes
# 1  /content/Internship_Ravali_Musquare Technologi...  Intern Resumes

# %%
# List of remaining files
peoplesoft_files = [
    '/content/Peoplesoft Admin_Gangareddy.docx',
    '/content/Peoplesoft Finance_Pritam Biswas.docx',
    '/content/Peoplesoft Admin_Priyanka Ramadoss.docx',
    '/content/Peoplesoft Admin_G Ananda Rayudu.docx',
    '/content/Peoplesoft Finance_Rahul Ahuja.docx',
    '/content/PeopleSoft DBA_Vivekanand Sayana.docx',
    '/content/Peoplesoft Admin_Murali.docx',
    '/content/Peoplesoft FSCM_R Ahmed.docx',
    '/content/Peoplesoft Admin_SirazuddinMohammad.docx',
    '/content/Peoplesoft FSCM_PriyabrataHota.docx',
    '/content/Peoplesoft Admin_AnubhavSingh.docx',
    '/content/Resume_Subha Santosh_Peoplesoft FSCM.docx',
    '/content/Peoplesoft Admin_Varkala Vikas.docx',
    '/content/Peoplesoft FSCM_SUJATHA.docx',
    '/content/Peoplesoft FSCM_Murali.docx',
    '/content/Peoplesoft Admin_Vinod Akkala.docx',
    '/content/Peoplesoft FSCM_HariNarayana.docx',
    '/content/Peoplesoft Finance_Arun Venu.docx',
    '/content/PeopleSoft DBA_Ganesh Alladi.docx'
]

# Create the DataFrame for Peoplesoft resumes
df_peoplesoft = pd.DataFrame({
    'Resume': peoplesoft_files,
    'category': 'Peoplesoft Resumes'
})

# Display the DataFrame
display(df_peoplesoft)
# Out:
#                                                Resume            category
# 0           /content/Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resumes
# 1      /content/Peoplesoft Finance_Pritam Biswas.docx  Peoplesoft Resumes
# 2    /content/Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resumes
# 3      /content/Peoplesoft Admin_G Ananda Rayudu.docx  Peoplesoft Resumes
# 4        /content/Peoplesoft Finance_Rahul Ahuja.docx  Peoplesoft Resumes
# 5      /content/PeopleSoft DBA_Vivekanand Sayana.docx  Peoplesoft Resumes
# 6               /content/Peoplesoft Admin_Murali.docx  Peoplesoft Resumes
# 7               /content/Peoplesoft FSCM_R Ahmed.docx  Peoplesoft Resumes
# 8   /content/Peoplesoft Admin_SirazuddinMohammad.docx  Peoplesoft Resumes
# 9        /content/Peoplesoft FSCM_PriyabrataHota.docx  Peoplesoft Resumes
# 10        /content/Peoplesoft Admin_AnubhavSingh.docx  Peoplesoft Resumes
# 11  /content/Resume_Subha Santosh_Peoplesoft FSCM....  Peoplesoft Resumes
# ...

# %%
# List of remaining files (React Js Resumes)
react_files = [
    '/content/Reactjs Developer_Shaik Abdul Sharuk_Musquare Technologies.docx',
    '/content/Reactjs Developer_Prabakaran_Musquare Technologies.docx',
    '/content/Reactjs Developer_M Lokesh.docx',
    '/content/Reactjs Developer_Pranish Sonone_Musquare Technologies.docx',
    '/content/React Developer_Vinay Reddy.docx',
    '/content/React Developer_Naveen sadhu.docx',
    '/content/React JS Developer_Venkatalakshmi (1)-converted.docx',
    '/content/Reactjs Developer_M Lokesh Babu_Musquare Technologies.docx',
    '/content/React JS Developer_AnjaniPriyadarshini.docx',
    '/content/React Dev_Krishna Kanth.docx',
    '/content/Reactjs Developer_Ranga Gaganam_Musquare Technologies.docx',
    '/content/Reactjs Developer_kambala sai surendra_Musquare Technologies.docx',
    '/content/React Developer_Kamalakar Reddy.docx',
    '/content/React Developer_Deepakreddy.docx',
    '/content/React Dev_Krishna Kanth_Musquare Technologies.docx',
    '/content/React Developer_PavasGoswami.docx',
    '/content/React Developer_Pragnya.docx',
    '/content/React Developer_Haripriya.docx',
    '/content/React JS Developer_KotaniDurgaprasad[3_1] (1)-converted.docx',
    '/content/React Developer_Thirupathiamma.docx',
    '/content/Reactjs Developer_MD Khizaruddin Rauf _Musquare Technologies.docx',
    '/content/React Developer_Sarala Madasu-converted.docx'
]

# Create the DataFrame for React Js resumes
df_react = pd.DataFrame({
    'Resume': react_files,
    'category': 'React Js Resumes'
})

# Display the DataFrame
display(df_react)
# Out:
#                                                Resume          category
# 0   /content/Reactjs Developer_Shaik Abdul Sharuk_...  React Js Resumes
# 1   /content/Reactjs Developer_Prabakaran_Musquare...  React Js Resumes
# 2            /content/Reactjs Developer_M Lokesh.docx  React Js Resumes
# 3   /content/Reactjs Developer_Pranish Sonone_Musq...  React Js Resumes
# 4           /content/React Developer_Vinay Reddy.docx  React Js Resumes
# 5          /content/React Developer_Naveen sadhu.docx  React Js Resumes
# 6   /content/React JS Developer_Venkatalakshmi (1)...  React Js Resumes
# 7   /content/Reactjs Developer_M Lokesh Babu_Musqu...  React Js Resumes
# 8   /content/React JS Developer_AnjaniPriyadarshin...  React Js Resumes
# 9               /content/React Dev_Krishna Kanth.docx  React Js Resumes
# 10  /content/Reactjs Developer_Ranga Gaganam_Musqu...  React Js Resumes
# 11  /content/Reactjs Developer_kambala sai surendr...  React Js Resumes
# ...

# %%
# List of remaining files (SQL Resumes)
sql_files = [
    '/content/Rajupavanakumari[2_10].docx',
    '/content/kamballapradeep.docx',
    '/content/premsai.docx',
    '/content/RameshNataru[3_4].docx',
    '/content/Ramalakshmi K.docx',
    '/content/Anil kumar.docx',
    '/content/Priyanka L.docx',
    '/content/PSyamKumar[2_3].docx',
    '/content/Buddha Vamsi.docx',
    '/content/Tatikonda Kiran Kumar.docx',
    '/content/AradhanaTripathi[4_0].docx',
    '/content/Vinod B.docx',
    '/content/Nazeer Basha.docx',
    '/content/Peoplesoft Admin_srinivasarao.docx',
    '/content/Neeraj Mishra.docx'
]

# Create the DataFrame for SQL resumes
df_sql = pd.DataFrame({
    'Resume': sql_files,
    'category': 'SQL Resumes'
})

# Display the DataFrame
display(df_sql)
# Out:
#                                          Resume     category
# 0          /content/Rajupavanakumari[2_10].docx  SQL Resumes
# 1                 /content/kamballapradeep.docx  SQL Resumes
# 2                         /content/premsai.docx  SQL Resumes
# 3               /content/RameshNataru[3_4].docx  SQL Resumes
# 4                   /content/Ramalakshmi K.docx  SQL Resumes
# 5                      /content/Anil kumar.docx  SQL Resumes
# 6                      /content/Priyanka L.docx  SQL Resumes
# 7                 /content/PSyamKumar[2_3].docx  SQL Resumes
# 8                    /content/Buddha Vamsi.docx  SQL Resumes
# 9           /content/Tatikonda Kiran Kumar.docx  SQL Resumes
# 10          /content/AradhanaTripathi[4_0].docx  SQL Resumes
# 11                        /content/Vinod B.docx  SQL Resumes
# 12                   /content/Nazeer Basha.docx  SQL Resumes
# 13  /content/Peoplesoft Admin_srinivasarao.docx  SQL Resumes
# ...

# %%
# List of remaining files (Workday Resumes)
workday_files = [
    '/content/MooraboyinaGuravaiah_Hexaware.docx',
    '/content/Himaja G_(Hexaware).docx',
    '/content/Venkateswarlu B_Hexaware.docx',
    '/content/Hima Mendu_Hexaware.docx',
    '/content/Sri Krishna S_Hexaware.docx',
    '/content/Srikanth-Hexaware.docx',
    '/content/Punugoti Swetha_Hexaware.docx',
    '/content/Hari Krishna M_Hexaware.docx',
    '/content/Harikrishna Akula_Hexaware.docx',
    '/content/RahulM_Hexaware.docx',
    '/content/Vinay Kumar_Hexaware.docx',
    '/content/P V Sai Krishna_ Hexaware.docx',
    '/content/Naresh Babu Cherukuri_Hexaware.docx',
    '/content/Madeeswar A_Hexaware.docx',
    '/content/SSKumar_Hexaware.docx',
    '/content/Jyotiverma_Heaware.docx',
    '/content/Gopi Krishna_Hexaware.docx',
    '/content/RameshP_Hexaware.docx',
    '/content/ShireeshKumar_Hexaware.docx',
    '/content/J. Sumanth Royal_Hexaware.docx',
    '/content/ChinnaSubbarayuduM_Hexaware.docx'
]

# Create the DataFrame for Workday resumes
df_workday = pd.DataFrame({
    'Resume': workday_files,
    'category': 'Workday Resumes'
})

# Display the DataFrame
display(df_workday)
# Out:
#                                           Resume         category
# 0    /content/MooraboyinaGuravaiah_Hexaware.docx  Workday Resumes
# 1              /content/Himaja G_(Hexaware).docx  Workday Resumes
# 2         /content/Venkateswarlu B_Hexaware.docx  Workday Resumes
# 3              /content/Hima Mendu_Hexaware.docx  Workday Resumes
# 4           /content/Sri Krishna S_Hexaware.docx  Workday Resumes
# 5                /content/Srikanth-Hexaware.docx  Workday Resumes
# 6         /content/Punugoti Swetha_Hexaware.docx  Workday Resumes
# 7          /content/Hari Krishna M_Hexaware.docx  Workday Resumes
# 8       /content/Harikrishna Akula_Hexaware.docx  Workday Resumes
# 9                  /content/RahulM_Hexaware.docx  Workday Resumes
# 10            /content/Vinay Kumar_Hexaware.docx  Workday Resumes
# 11       /content/P V Sai Krishna_ Hexaware.docx  Workday Resumes
# 12  /content/Naresh Babu Cherukuri_Hexaware.docx  Workday Resumes
# ...

# %%
# Combine all DataFrames into a single one
df = pd.concat([df, df_peoplesoft, df_react, df_sql, df_workday], ignore_index=True)

# Display the combined DataFrame
display(df)
# Out:
#                                                Resume            category
# 0   /content/Internship_Susovan Bag_Musquare Techn...      Intern Resumes
# 1   /content/Internship_Ravali_Musquare Technologi...      Intern Resumes
# 2           /content/Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resumes
# 3      /content/Peoplesoft Finance_Pritam Biswas.docx  Peoplesoft Resumes
# 4    /content/Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resumes
# ..                                                ...                 ...
# 74                /content/Gopi Krishna_Hexaware.docx     Workday Resumes
# 75                     /content/RameshP_Hexaware.docx     Workday Resumes
# 76               /content/ShireeshKumar_Hexaware.docx     Workday Resumes
# 77            /content/J. Sumanth Royal_Hexaware.docx     Workday Resumes
# 78          /content/ChinnaSubbarayuduM_Hexaware.docx     Workday Resumes
#
# [79 rows x 2 columns]

# %% [markdown]
# # Task
# Preprocess the text in the `Resume` column of the DataFrame `df` using natural language processing techniques.

# %%
df["category"].value_counts()
# Out:
# category
# React Js Resumes      22
# Workday Resumes       21
# Peoplesoft Resumes    19
# SQL Resumes           15
# Intern Resumes         2
# Name: count, dtype: int64

# %% [markdown]
# ## Install necessary libraries
#
# ### Subtask:
# Install libraries required for reading `.docx` files and performing text preprocessing.

# %% [markdown]
# **Reasoning**:
# Install the required libraries and download the NLTK stopwords corpus.

# %%
# %pip install python-docx nltk
import nltk
nltk.download('stopwords')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 11.1 MB/s eta 0:00:00
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# ## Define text extraction function
#
# ### Subtask:
# Create a function to extract text content from each `.docx` file path listed in the 'Resume' column.

# %% [markdown]
# **Reasoning**:
# Define a function to extract text from docx files as instructed.

# %%
from docx import Document

def extract_text_from_docx(filepath):
    """
    Extracts text content from a .docx file.

    Args:
        filepath (str): The path to the .docx file.

    Returns:
        str: The extracted text content from the file.
    """
    document = Document(filepath)
    text = ''
    for paragraph in document.paragraphs:
        text += paragraph.text + '\n'
    return text

# %% [markdown]
# ## Apply text extraction
#
# ### Subtask:
# Apply the text extraction function to the 'Resume' column and store the extracted text in a new column (e.g., 'text').

# %% [markdown]
# **Reasoning**:
# Apply the text extraction function to the 'Resume' column and store the results in a new column named 'text'.

# %%
df['text'] = df['Resume'].apply(extract_text_from_docx)
display(df.head())
# Out:
#                                               Resume            category  \
# 0  /content/Internship_Susovan Bag_Musquare Techn...      Intern Resumes
# 1  /content/Internship_Ravali_Musquare Technologi...      Intern Resumes
# 2          /content/Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resumes
# 3     /content/Peoplesoft Finance_Pritam Biswas.docx  Peoplesoft Resumes
# 4   /content/Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resumes
#
#                                                 text
# 0    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...
# 1  Name: Ravali P \n\n                           ...
# 2  PeopleSoft Database Administrator\n           ...
# 3  \n\n\n\n\nExperience Summary\n4.1 years- Exper...
# 4  Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...

# %% [markdown]
# ## Define text preprocessing function
#
# ### Subtask:
# Create a function to clean the extracted text. This may include steps like removing punctuation, converting to lowercase, and removing stop words.

# %% [markdown]
# **Reasoning**:
# Define the `clean_text` function to preprocess the text data by converting to lowercase, removing punctuation, tokenizing, and removing stop words.

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def clean_text(text):
    """
    Cleans the input text by converting to lowercase, removing punctuation,
    tokenizing, and removing stop words.

    Args:
        text (str): The input text string.

    Returns:
        str: The cleaned text string.
    """
    # Convert to lowercase
    text = text.lower()

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenize
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    cleaned_tokens = [word for word in tokens if word not in stop_words]

    # Join tokens back into a string
    cleaned_text = ' '.join(cleaned_tokens)

    return cleaned_text

# %% [markdown]
# ## Apply text preprocessing
#
# ### Subtask:
# Apply the text preprocessing function to the 'text' column and store the cleaned text in a new column (e.g., 'cleaned_text').

# %% [markdown]
# **Reasoning**:
# Apply the text preprocessing function to the 'text' column and store the cleaned text in a new column, then display the head of the dataframe to verify.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
df['cleaned_text'] = df['text'].apply(clean_text)
display(df.head())
# Out:
#                                               Resume            category  \
# 0  /content/Internship_Susovan Bag_Musquare Techn...      Intern Resumes
# 1  /content/Internship_Ravali_Musquare Technologi...      Intern Resumes
# 2          /content/Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resumes
# 3     /content/Peoplesoft Finance_Pritam Biswas.docx  Peoplesoft Resumes
# 4   /content/Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resumes
#
#                                                 text  \
# 0    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...
# 1  Name: Ravali P \n\n                           ...
# 2  PeopleSoft Database Administrator\n           ...
# 3  \n\n\n\n\nExperience Summary\n4.1 years- Exper...
# 4  Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...
#
#                                         cleaned_text
# 0  susovan bag seeking challenging position field...
# 1  name ravali p curriculum vitae specialization ...
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The necessary libraries for text extraction and preprocessing (`python-docx` and `nltk`) and the 'stopwords' corpus were already available in the environment.
# *   A function `extract_text_from_docx` was successfully created to extract text from `.docx` files.
# *   The text from the 'Resume' column was successfully extracted and stored in a new 'text' column.
# *   A `clean_text` function was defined to preprocess the extracted text by converting to lowercase, removing punctuation, tokenizing, and removing stop words.
# *   Applying the `clean_text` function required downloading the 'punkt' and 'punkt\_tab' NLTK resources to resolve `LookupError` during tokenization.
# *   A new 'cleaned\_text' column containing the preprocessed text was successfully added to the DataFrame.
#
# ### Insights or Next Steps
#
# *   The cleaned text in the 'cleaned\_text' column is now ready for further analysis, such as feature extraction (e.g., TF-IDF, word embeddings) for machine learning tasks like resume classification or keyword extraction.
# *   Consider exploring other text preprocessing steps, such as stemming or lemmatization, depending on the specific downstream analysis requirements.

# %% [markdown]
# # Task
# Preprocess the text in the 'Resume' column of the DataFrame `df` using natural language processing techniques, including text extraction, cleaning, and lemmatization.

# %% [markdown]
# ## Download nltk resource for lemmatization
#
# ### Subtask:
# Download the 'wordnet' corpus required for lemmatization.

# %% [markdown]
# **Reasoning**:
# Download the 'wordnet' corpus using NLTK downloader as instructed.

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# ## Define lemmatization function
#
# ### Subtask:
# Create a function to apply lemmatization to the cleaned text.

# %% [markdown]
# **Reasoning**:
# Define a function to apply lemmatization to the cleaned text using NLTK's WordNetLemmatizer as instructed.

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    """
    Applies lemmatization to the input text.

    Args:
        text (str): The input text string.

    Returns:
        str: The lemmatized text string.
    """
    tokens = word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]
    lemmatized_text = ' '.join(lemmatized_tokens)
    return lemmatized_text

# %% [markdown]
# ## Apply lemmatization
#
# ### Subtask:
# Apply the lemmatization function to the 'cleaned_text' column and store the lemmatized text in a new column (e.g., 'lemmatized_text').

# %% [markdown]
# **Reasoning**:
# Apply the lemmatization function to the 'cleaned_text' column and store the lemmatized text in a new column, then display the head of the dataframe to verify.

# %%
df['lemmatized_text'] = df['cleaned_text'].apply(lemmatize_text)
display(df.head())
# Out:
#                                               Resume            category  \
# 0  /content/Internship_Susovan Bag_Musquare Techn...      Intern Resumes
# 1  /content/Internship_Ravali_Musquare Technologi...      Intern Resumes
# 2          /content/Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resumes
# 3     /content/Peoplesoft Finance_Pritam Biswas.docx  Peoplesoft Resumes
# 4   /content/Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resumes
#
#                                                 text  \
# 0    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...
# 1  Name: Ravali P \n\n                           ...
# 2  PeopleSoft Database Administrator\n           ...
# 3  \n\n\n\n\nExperience Summary\n4.1 years- Exper...
# 4  Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...
#
#                                         cleaned_text  \
# 0  susovan bag seeking challenging position field...
# 1  name ravali p curriculum vitae specialization ...
# ...

# %% [markdown]
# **Reasoning**:
# The error indicates that the column 'cleaned_text' does not exist in the DataFrame. Re-run the code to apply the cleaning function and create the 'cleaned_text' column before attempting to apply lemmatization.

# %%
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from docx import Document
from nltk.stem import WordNetLemmatizer

# Define the text extraction function
def extract_text_from_docx(filepath):
    document = Document(filepath)
    text = ''
    for paragraph in document.paragraphs:
        text += paragraph.text + '\n'
    return text

# Define the text cleaning function
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    cleaned_tokens = [word for word in tokens if word not in stop_words]
    cleaned_text = ' '.join(cleaned_tokens)
    return cleaned_text

# Define the lemmatization function
lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    tokens = word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]
    lemmatized_text = ' '.join(lemmatized_tokens)
    return lemmatized_text

# Apply text extraction
df['text'] = df['Resume'].apply(extract_text_from_docx)

# Apply text preprocessing
df['cleaned_text'] = df['text'].apply(clean_text)

# Apply lemmatization
df['lemmatized_text'] = df['cleaned_text'].apply(lemmatize_text)
display(df.head())
# Out:
#                                               Resume            category  \
# 0  /content/Internship_Susovan Bag_Musquare Techn...      Intern Resumes
# 1  /content/Internship_Ravali_Musquare Technologi...      Intern Resumes
# 2          /content/Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resumes
# 3     /content/Peoplesoft Finance_Pritam Biswas.docx  Peoplesoft Resumes
# 4   /content/Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resumes
#
#                                                 text  \
# 0    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...
# 1  Name: Ravali P \n\n                           ...
# 2  PeopleSoft Database Administrator\n           ...
# 3  \n\n\n\n\nExperience Summary\n4.1 years- Exper...
# 4  Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...
#
#                                         cleaned_text  \
# 0  susovan bag seeking challenging position field...
# 1  name ravali p curriculum vitae specialization ...
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The 'wordnet' corpus, necessary for lemmatization, was successfully downloaded.
# *   A Python function `lemmatize_text` was defined to apply lemmatization using NLTK's `WordNetLemmatizer`.
# *   The entire text preprocessing pipeline, including text extraction from .docx files, cleaning (lowercase conversion, punctuation removal, stop word removal), and lemmatization, was successfully applied to the DataFrame, creating 'text', 'cleaned\_text', and 'lemmatized\_text' columns.
#
# ### Insights or Next Steps
#
# *   The preprocessed text in the 'lemmatized\_text' column is now ready for further natural language processing tasks, such as feature extraction (e.g., TF-IDF), topic modeling, or text classification.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the occurrences of each category
category_counts = df['category'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=category_counts.index, y=category_counts.values)
plt.title('Distribution of Resume Categories')
plt.xlabel('Category')
plt.ylabel('Number of Resumes')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Task
# Load resume files from "Intern Resumes", "Peoplesoft Resumes", "React Js Resumes", "SQL Resumes", and "Workday Resumes" categories into separate dataframes, combine them into a single dataframe named `df`, preprocess the text in the 'Resume' column using NLP techniques including lemmatization, and visualize the data using bar graphs, including visualizations of text before and after preprocessing and the length of words for 'Resume', 'text', 'cleaned_text', and 'lemmatized_text' columns.

# %% [markdown]
# ## Calculate word lengths
#
# ### Subtask:
# Calculate the number of words in each entry of the 'Resume', 'text', 'cleaned_text', and 'lemmatized_text' columns.

# %% [markdown]
# **Reasoning**:
# Calculate the number of words for each of the specified columns and store them in new columns, then display the head of the dataframe.

# %%
df['Resume_word_count'] = df['Resume'].apply(lambda x: len(x.split()))
df['text_word_count'] = df['text'].apply(lambda x: len(x.split()))
df['cleaned_text_word_count'] = df['cleaned_text'].apply(lambda x: len(x.split()))
df['lemmatized_text_word_count'] = df['lemmatized_text'].apply(lambda x: len(x.split()))

display(df.head())
# Out:
#                                               Resume            category  \
# 0  /content/Internship_Susovan Bag_Musquare Techn...      Intern Resumes
# 1  /content/Internship_Ravali_Musquare Technologi...      Intern Resumes
# 2          /content/Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resumes
# 3     /content/Peoplesoft Finance_Pritam Biswas.docx  Peoplesoft Resumes
# 4   /content/Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resumes
#
#                                                 text  \
# 0    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...
# 1  Name: Ravali P \n\n                           ...
# 2  PeopleSoft Database Administrator\n           ...
# 3  \n\n\n\n\nExperience Summary\n4.1 years- Exper...
# 4  Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...
#
#                                         cleaned_text  \
# 0  susovan bag seeking challenging position field...
# 1  name ravali p curriculum vitae specialization ...
# ...

# %% [markdown]
# ## Visualize word length distributions
#
# ### Subtask:
# Create bar plots or histograms to visualize the distribution of word lengths for each of the specified columns.

# %% [markdown]
# **Reasoning**:
# Create bar plots to visualize the distribution of word lengths for each of the specified columns using subplots as instructed.

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

sns.histplot(df['Resume_word_count'], ax=axes[0, 0], kde=True)
axes[0, 0].set_title('Distribution of Resume Path Word Lengths')
axes[0, 0].set_xlabel('Word Count')
axes[0, 0].set_ylabel('Frequency')

sns.histplot(df['text_word_count'], ax=axes[0, 1], kde=True)
axes[0, 1].set_title('Distribution of Extracted Text Word Lengths')
axes[0, 1].set_xlabel('Word Count')
axes[0, 1].set_ylabel('Frequency')

sns.histplot(df['cleaned_text_word_count'], ax=axes[1, 0], kde=True)
axes[1, 0].set_title('Distribution of Cleaned Text Word Lengths')
axes[1, 0].set_xlabel('Word Count')
axes[1, 0].set_ylabel('Frequency')

sns.histplot(df['lemmatized_text_word_count'], ax=axes[1, 1], kde=True)
axes[1, 1].set_title('Distribution of Lemmatized Text Word Lengths')
axes[1, 1].set_xlabel('Word Count')
axes[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The number of words in the 'Resume', 'text', 'cleaned\_text', and 'lemmatized\_text' columns were calculated and stored in new columns: 'Resume\_word\_count', 'text\_word\_count', 'cleaned\_text\_word\_count', and 'lemmatized\_text\_word\_count'.
# *   Histograms visualizing the distribution of word counts for each of these columns were successfully generated, showing how the word lengths are distributed across different stages of text processing.
#
# ### Insights or Next Steps
#
# *   Analyze the changes in word count distributions between the original 'Resume' text and the preprocessed versions to understand the impact of each preprocessing step (text extraction, cleaning, and lemmatization).
# *   Consider calculating additional text metrics like average word length or unique word count to gain further insights into the characteristics of the resume text data.

# %% [markdown]
# # Task
# Generate word clouds for the 'Resume', 'text', 'cleaned_text', and 'lemmatized_text' columns of the dataframe.

# %% [markdown]
# ## Install necessary libraries
#
# ### Subtask:
# Install the `wordcloud` library if it's not already installed.

# %% [markdown]
# **Reasoning**:
# Install the `wordcloud` library using pip.

# %%
# %pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_wordcloud(text_column, title):
    """
    Generates and displays a word cloud for a given text column.

    Args:
        text_column (pd.Series): The pandas Series containing the text data.
        title (str): The title for the word cloud plot.
    """
    # Combine all text in the column into a single string
    text = " ".join(text_column.dropna())

    # Generate the word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud
    plt.figure(figsize=(10, 7))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    plt.show()

# Generate word clouds for the specified columns
text_columns = ['Resume', 'text', 'cleaned_text', 'lemmatized_text']
column_titles = {
    'Resume': 'Word Cloud for Resume Paths',
    'text': 'Word Cloud for Extracted Text',
    'cleaned_text': 'Word Cloud for Cleaned Text',
    'lemmatized_text': 'Word Cloud for Lemmatized Text'
}

for col in text_columns:
    generate_wordcloud(df[col], column_titles[col])

# %%
df.head()
# Out:
#                                               Resume            category  \
# 0  /content/Internship_Susovan Bag_Musquare Techn...      Intern Resumes
# 1  /content/Internship_Ravali_Musquare Technologi...      Intern Resumes
# 2          /content/Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resumes
# 3     /content/Peoplesoft Finance_Pritam Biswas.docx  Peoplesoft Resumes
# 4   /content/Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resumes
#
#                                                 text  \
# 0    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...
# 1  Name: Ravali P \n\n                           ...
# 2  PeopleSoft Database Administrator\n           ...
# 3  \n\n\n\n\nExperience Summary\n4.1 years- Exper...
# 4  Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...
#
#                                         cleaned_text  \
# 0  susovan bag seeking challenging position field...
# 1  name ravali p curriculum vitae specialization ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode the 'category' column
df['category_encoded'] = label_encoder.fit_transform(df['category'])

# Display the updated DataFrame with the new encoded column
display(df.head())
# Out:
#                                               Resume            category  \
# 0  /content/Internship_Susovan Bag_Musquare Techn...      Intern Resumes
# 1  /content/Internship_Ravali_Musquare Technologi...      Intern Resumes
# 2          /content/Peoplesoft Admin_Gangareddy.docx  Peoplesoft Resumes
# 3     /content/Peoplesoft Finance_Pritam Biswas.docx  Peoplesoft Resumes
# 4   /content/Peoplesoft Admin_Priyanka Ramadoss.docx  Peoplesoft Resumes
#
#                                                 text  \
# 0    \nSUSOVAN  BAG   \nSeeking  a  challenging  ...
# 1  Name: Ravali P \n\n                           ...
# 2  PeopleSoft Database Administrator\n           ...
# 3  \n\n\n\n\nExperience Summary\n4.1 years- Exper...
# 4  Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...
#
#                                         cleaned_text  \
# 0  susovan bag seeking challenging position field...
# 1  name ravali p curriculum vitae specialization ...
# ...

# %%
df["category_encoded"].value_counts()
# Out:
# category_encoded
# 2    22
# 4    21
# 1    19
# 3    15
# 0     2
# Name: count, dtype: int64

# %% [markdown]
# ## Feature Extraction using TF-IDF
#
# ### Subtask:
# Apply TF-IDF vectorization to the 'lemmatized_text' column to convert text data into numerical feature vectors.

# %% [markdown]
# **Reasoning**:
# Apply TF-IDF vectorization to the 'lemmatized_text' column using `TfidfVectorizer` and display the shape of the resulting matrix.

# %%
X =  df["lemmatized_text"]
Y = df["category_encoded"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib

vectorizer = TfidfVectorizer(stop_words="english", max_features=5000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Save the fitted TF-IDF vectorizer
joblib.dump(vectorizer, 'tfidf_vectorizer.pkl')
# Out:
# ['tfidf_vectorizer.pkl']

# %%
from sklearn.linear_model import LogisticRegression

# Initialize Logistic Regression model
logistic_regression_model = LogisticRegression(max_iter=1000) # Increased max_iter for convergence

# Train the model
logistic_regression_model.fit(X_train_tfidf, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions on the test set
y_pred = logistic_regression_model.predict(X_test_tfidf)

# Evaluate the model
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Print classification report
print("Classification Report:")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy: 0.9375
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       1.00      1.00      1.00         4
#            2       0.86      1.00      0.92         6
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         3
#
#     accuracy                           0.94        16
#    macro avg       0.77      0.80      0.78        16
# weighted avg       0.88      0.94      0.91        16
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.metrics import log_loss

# Get predicted probabilities for the test set
y_pred_proba = logistic_regression_model.predict_proba(X_test_tfidf)

# Calculate log loss
loss = log_loss(Y_test, y_pred_proba)

print(f"Log Loss on the test set: {loss}")
# Out:
# Log Loss on the test set: 0.6989868494720414

# %%
from sklearn.naive_bayes import MultinomialNB

# Initialize Multinomial Naive Bayes model
naive_bayes_model = MultinomialNB()

# Train the model
naive_bayes_model.fit(X_train_tfidf, Y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions on the test set
y_pred_nb = naive_bayes_model.predict(X_test_tfidf)

# Evaluate the model
accuracy_nb = accuracy_score(Y_test, y_pred_nb)
print(f"Naive Bayes Model Accuracy: {accuracy_nb}")

# Print classification report
print("Naive Bayes Model Classification Report:")
print(classification_report(Y_test, y_pred_nb))
# Out:
# Naive Bayes Model Accuracy: 0.9375
# Naive Bayes Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       1.00      1.00      1.00         4
#            2       0.86      1.00      0.92         6
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         3
#
#     accuracy                           0.94        16
#    macro avg       0.77      0.80      0.78        16
# weighted avg       0.88      0.94      0.91        16
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.metrics import log_loss

# Get predicted probabilities for the test set from the Naive Bayes model
y_pred_proba_nb = naive_bayes_model.predict_proba(X_test_tfidf)

# Calculate log loss for the Naive Bayes model
loss_nb = log_loss(Y_test, y_pred_proba_nb)

print(f"Log Loss for Naive Bayes Model on the test set: {loss_nb}")
# Out:
# Log Loss for Naive Bayes Model on the test set: 0.7059776975862877

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for GridSearchCV
param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'kernel': ['rbf', 'linear']}

# Initialize the SVM model
svm_model = SVC()

# Initialize GridSearchCV
grid_search = GridSearchCV(svm_model, param_grid, refit=True, verbose=3)

# Fit GridSearchCV to the training data
grid_search.fit(X_train_tfidf, Y_train)

# Print the best parameters found
print("Best parameters found by GridSearchCV:")
print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.308 total time=   0.0s
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.308 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.308 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.250 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.250 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.308 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.308 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.308 total time=   0.0s
# ...

# %%
from sklearn.svm import SVC

# Initialize SVM model with the best parameters found by GridSearchCV
best_svm_model = SVC(C=1, gamma=1, kernel='linear')

# Train the model
best_svm_model.fit(X_train_tfidf, Y_train)
# Out:
# SVC(C=1, gamma=1, kernel='linear')

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions on the test set
y_pred_svm = best_svm_model.predict(X_test_tfidf)

# Evaluate the model
accuracy_svm = accuracy_score(Y_test, y_pred_svm)
print(f"SVM Model Accuracy: {accuracy_svm}")

# Print classification report
print("SVM Model Classification Report:")
print(classification_report(Y_test, y_pred_svm))
# Out:
# SVM Model Accuracy: 0.9375
# SVM Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       1.00      1.00      1.00         4
#            2       0.86      1.00      0.92         6
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         3
#
#     accuracy                           0.94        16
#    macro avg       0.77      0.80      0.78        16
# weighted avg       0.88      0.94      0.91        16
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for GridSearchCV for Decision Tree
param_grid_dt = {
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# Initialize the Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)

# Initialize GridSearchCV
grid_search_dt = GridSearchCV(dt_model, param_grid_dt, refit=True, verbose=3)

# Fit GridSearchCV to the training data
grid_search_dt.fit(X_train_tfidf, Y_train)

# Print the best parameters found
print("Best parameters found by GridSearchCV for Decision Tree:")
print(grid_search_dt.best_params_)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.923 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.923 total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.923 total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=1.000 total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.923 total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5;, score=0.923 total time=   0.0s
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize Decision Tree model with the best parameters found by GridSearchCV
best_dt_model = DecisionTreeClassifier(criterion='gini', max_depth=None, min_samples_leaf=1, min_samples_split=2, random_state=42)

# Train the model
best_dt_model.fit(X_train_tfidf, Y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions on the test set
y_pred_dt = best_dt_model.predict(X_test_tfidf)

# Evaluate the model
accuracy_dt = accuracy_score(Y_test, y_pred_dt)
print(f"Decision Tree Model Accuracy: {accuracy_dt}")

# Print classification report
print("Decision Tree Model Classification Report:")
print(classification_report(Y_test, y_pred_dt))
# Out:
# Decision Tree Model Accuracy: 0.9375
# Decision Tree Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       1.00      1.00      1.00         4
#            2       0.86      1.00      0.92         6
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         3
#
#     accuracy                           0.94        16
#    macro avg       0.77      0.80      0.78        16
# weighted avg       0.88      0.94      0.91        16
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for GridSearchCV for KNN
param_grid_knn = {'n_neighbors': [3, 5, 7, 9, 11]} # You can adjust the range of k values

# Initialize the KNN model
knn_model = KNeighborsClassifier()

# Initialize GridSearchCV
grid_search_knn = GridSearchCV(knn_model, param_grid_knn, refit=True, verbose=3)

# Fit GridSearchCV to the training data
grid_search_knn.fit(X_train_tfidf, Y_train)

# Print the best parameters found
print("Best parameters found by GridSearchCV for KNN:")
print(grid_search_knn.best_params_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV 1/5] END .....................n_neighbors=3;, score=0.923 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=3;, score=0.923 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=3;, score=0.923 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=3;, score=1.000 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=5;, score=0.923 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=5;, score=0.923 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=5;, score=0.923 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=5;, score=1.000 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=5;, score=1.000 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=7;, score=1.000 total time=   0.0s
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize KNN model with the best parameter found by GridSearchCV
best_knn_model = KNeighborsClassifier(n_neighbors=9)

# Train the model
best_knn_model.fit(X_train_tfidf, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions on the test set
y_pred_knn = best_knn_model.predict(X_test_tfidf)

# Evaluate the model
accuracy_knn = accuracy_score(Y_test, y_pred_knn)
print(f"KNN Model Accuracy: {accuracy_knn}")

# Print classification report
print("KNN Model Classification Report:")
print(classification_report(Y_test, y_pred_knn))
# Out:
# KNN Model Accuracy: 0.9375
# KNN Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       1.00      1.00      1.00         4
#            2       0.86      1.00      0.92         6
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         3
#
#     accuracy                           0.94        16
#    macro avg       0.77      0.80      0.78        16
# weighted avg       0.88      0.94      0.91        16
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a dictionary with model names and their accuracy scores
model_accuracies = {
    'Logistic Regression': accuracy,
    'Naive Bayes': accuracy_nb,
    'SVM': accuracy_svm,
    'Decision Tree': accuracy_dt,
    'KNN': accuracy_knn
}

# Convert the dictionary to a pandas Series for easy plotting
accuracy_series = pd.Series(model_accuracies)

# Create a bar plot to compare accuracies
plt.figure(figsize=(10, 6))
sns.barplot(x=accuracy_series.index, y=accuracy_series.values)
plt.title('Comparison of Model Accuracies')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.ylim(0, 1) # Set y-axis limit from 0 to 1 for accuracy
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Save the best Decision Tree model
joblib.dump(best_dt_model, 'best_decision_tree_model.pkl')
# Out:
# ['best_decision_tree_model.pkl']

# %%
pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 76.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 90.2 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import joblib
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Load the saved TF-IDF vectorizer and the trained model
vectorizer = joblib.load('tfidf_vectorizer.pkl')
model = joblib.load('best_decision_tree_model.pkl')

# Define the text cleaning and lemmatization functions (same as used during training)
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = word_tokenize(text)
    cleaned_tokens = [word for word in tokens if word not in stop_words]
    cleaned_text = ' '.join(cleaned_tokens)
    return cleaned_text

def lemmatize_text(text):
    tokens = word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]
    lemmatized_text = ' '.join(lemmatized_tokens)
    return lemmatized_text


# Create the Streamlit application
st.title("Resume Category Predictor")

st.write("Enter the resume text below to predict its category.")

# Get user input
resume_text = st.text_area("Resume Text", height=300)

if st.button("Predict Category"):
    if resume_text:
        # Preprocess the input text
        cleaned_text = clean_text(resume_text)
        lemmatized_text = lemmatize_text(cleaned_text)

        # Transform the preprocessed text using the loaded vectorizer
        text_tfidf = vectorizer.transform([lemmatized_text])

        # Make the prediction
        prediction = model.predict(text_tfidf)

        # Decode the prediction (assuming you have the original label encoder or a mapping)
        # For simplicity, let's use a hardcoded mapping based on your earlier value counts:
        category_mapping = {
            0: 'Intern Resumes',
            1: 'Peoplesoft Resumes',
            2: 'React Js Resumes',
            3: 'SQL Resumes',
            4: 'Workday Resumes'
        }
        predicted_category = category_mapping.get(prediction[0], "Unknown Category")

        st.success(f"Predicted Category: {predicted_category}")
    else:
        st.warning("Please enter some text to predict the category.")
# Out:
# 2025-10-03 12:09:04.082 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 12:09:04.277
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-10-03 12:09:04.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 12:09:04.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 12:09:04.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 12:09:04.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-03 12:09:04.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %% [markdown]
# Now, let's create a Python file for the Streamlit application. This file will contain the code to load the saved vectorizer and model, create a simple user interface, and make predictions.
#
# **Note**: To run this Streamlit application, you will need to save the following code in a Python file (e.g., `app.py`) in the same directory as your saved `tfidf_vectorizer.pkl` and `best_decision_tree_model.pkl` files. Then, you can run the application from your terminal using the command `streamlit run app.py`.

# %%
# %%writefile app2.py
import streamlit as st
import joblib
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from docx import Document # Import Document for docx file reading

# Load the saved TF-IDF vectorizer and the trained model
vectorizer = joblib.load('tfidf_vectorizer.pkl')
model = joblib.load('best_decision_tree_model.pkl')

# Define the text cleaning and lemmatization functions (same as used during training)
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = word_tokenize(text)
    cleaned_tokens = [word for word in tokens if word not in stop_words]
    cleaned_text = ' '.join(cleaned_tokens)
    return cleaned_text

def lemmatize_text(text):
    tokens = word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]
    lemmatized_text = ' '.join(lemmatized_tokens)
    return lemmatized_text

def extract_text_from_docx(file):
    """
    Extracts text content from an uploaded .docx file.

    Args:
        file (file-like object): The uploaded .docx file.

    Returns:
        str: The extracted text content from the file.
    """
    document = Document(file)
    text = ''
    for paragraph in document.paragraphs:
        text += paragraph.text + '\n'
    return text

# Create the Streamlit application
st.title("Resume Category Predictor")

st.write("Upload a resume file (.docx) to predict its category.")

# Add file uploader
uploaded_file = st.file_uploader("Upload Resume File", type=["docx"])

if uploaded_file is not None:
    # Extract text from the uploaded file
    resume_text = extract_text_from_docx(uploaded_file)

    if st.button("Predict Category"):
        if resume_text:
            # Preprocess the extracted text
            cleaned_text = clean_text(resume_text)
            lemmatized_text = lemmatize_text(cleaned_text)

            # Transform the preprocessed text using the loaded vectorizer
            text_tfidf = vectorizer.transform([lemmatized_text])

            # Make the prediction
            prediction = model.predict(text_tfidf)

            # Decode the prediction (assuming you have the original label encoder or a mapping)
            # For simplicity, let's use a hardcoded mapping based on your earlier value counts:
            category_mapping = {
                0: 'Intern Resumes',
                1: 'Peoplesoft Resumes',
                2: 'React Js Resumes',
                3: 'SQL Resumes',
                4: 'Workday Resumes'
            }
            predicted_category = category_mapping.get(prediction[0], "Unknown Category")

            st.success(f"Predicted Category: {predicted_category}")
        else:
            st.warning("Could not extract text from the uploaded file.")
else:
    st.info("Please upload a .docx file to get a prediction.")
# Out:
# Writing app2.py

# %% [markdown]
# After running the cell above, you will have an `app.py` file in your Colab environment. You can then download this file along with `tfidf_vectorizer.pkl` and `best_decision_tree_model.pkl` to run the Streamlit application locally.
